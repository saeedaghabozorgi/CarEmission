# %% [markdown]
# # Fuel consumption linear regression
# Using scipy
# adding test/train

# %%
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
# !wget -O /resources/FuelConsumption.csv https://ibm.box.com/shared/static/ez95yurarnp0q31l9jl1ma51mh6qtxj2.csv
# Out:
# --2015-10-05 14:03:51--  https://ibm.box.com/shared/static/ez95yurarnp0q31l9jl1ma51mh6qtxj2.csv
# Resolving ibm.box.com... 74.112.185.182, 74.112.184.85
# Connecting to ibm.box.com|74.112.185.182|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ibm.app.box.com/shared/static/ez95yurarnp0q31l9jl1ma51mh6qtxj2.csv [following]
# --2015-10-05 14:03:51--  https://ibm.app.box.com/shared/static/ez95yurarnp0q31l9jl1ma51mh6qtxj2.csv
# Resolving ibm.app.box.com... 74.112.184.87, 74.112.185.87
# Connecting to ibm.app.box.com|74.112.184.87|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.boxcloud.com/d/1/Y1dKpJWTJ52n5sf8CHGQGadLEC1dO2_TGkPSrllGDwXpqmOusrc8lYkecGIVxZbGdbR7Idc9zl4WfNZcYiT6F-ZMiRgYMWnRRcoq7TC8hCO95EcTVFSldun2ZXGDcP6Vwsxse0XN6H69ZiapvJ2Lq-x5ONKg8Qamo_v3Z3mhcv4_r5KHYfKS7sNfveoZpTwVa8OXy0OtYD3hdviVF93QPc4P-RIyaGUEQfeKa1ssxSJGCfocWsgG6_Te6jhSXoZe-FUfaDM_QZQMu2SnFuMZYSJxhyS_5jm5Nz_adqIMuXvFNKoyn9PuFJsCwLK13uuGGvytR1KxQL4T71a---uPitDVCWJWN5_og1hMUgAmAruvhgu4JXpRdxOtNyo_YdQg9D18ZTXmDp3_rX42Qrr8DOG8wT4mJeplqiEmgCcmN9EVGfqRSGqrxAYY1tonhe-p9kD16TmDw98ej0afQ8RO1BAhy59H0OlC7gfS1JkoGqcFrF6dLST1QmKJ_W0v5qAGHxCU1KvNSq8zth2v2iYjqteRrDF80Bkn65jYvKyf2pYiF1_VGJhjgS_b4q03IxUJW0Kv_7gTJh-VS29In0HnlxkOcjjFy-N36sXkkiYWLM2QHLWtlEFXedE6FcwuwwmZISYtaV6KwS11x_IEc6aT7GHzViH1lbPRvkEmrEZU__Mw4MbTxOxXFnt8ywptV8wGLJT_9pYN4CX1WC9LtOwLglfFr0iIwi8H3qZhqJLmp0hNq-3HTHi1iSZilWU9fI443Tgsc8_iDi9ek-ENa3QarqCa0gI5n87QpI6pmN8fqSm50dB4kNYiCEB3P_AK2YYveMcxFbdlwEaH7mmOJsAfrFap26_X6ASO6gKbqJN_ycP6WWYE-Yc2ahRShVEAFNtKgND1CmIyTurKVd0vCCye4wqWkeZQiMlbGPGIpsZ_Oemte49lRpbC1mvu0Ds_NSFR2JeMWdwASryh5k5zhPUEQnImHKyJ7hyDSqe1OYzUtWJ8MXFE-t3xd8QRM374DIz8TRyeghYciF5QPzy3LNLy4WgadNre5AZryhMJWI5D5_t-FtwUAzoMAzYGtm84MxQ0Tl4KqhQ2ClyXyZvch-WiO0XCSWwYLDzLrZHsznLmBrV7p7uVmvV1i5i4FpI21ykmOk_3c1_1p7dAfHjc6kE3g8eCv4COQ9ZAYTlxo3bRIwpAMUE_jghiYLwP8dLk0YoRX7HWzl8aLBA6LBbn4jTm6Aq6-A_he3wC9206mhyGVj2_b-L-B8wj-G6FaLcCiHBrtkjH6dAVFoPHTretIJE./download [following]
# --2015-10-05 14:03:52--  https://dl.boxcloud.com/d/1/Y1dKpJWTJ52n5sf8CHGQGadLEC1dO2_TGkPSrllGDwXpqmOusrc8lYkecGIVxZbGdbR7Idc9zl4WfNZcYiT6F-ZMiRgYMWnRRcoq7TC8hCO95EcTVFSldun2ZXGDcP6Vwsxse0XN6H69ZiapvJ2Lq-x5ONKg8Qamo_v3Z3mhcv4_r5KHYfKS7sNfveoZpTwVa8OXy0OtYD3hdviVF93QPc4P-RIyaGUEQfeKa1ssxSJGCfocWsgG6_Te6jhSXoZe-FUfaDM_QZQMu2SnFuMZYSJxhyS_5jm5Nz_adqIMuXvFNKoyn9PuFJsCwLK13uuGGvytR1KxQL4T71a---uPitDVCWJWN5_og1hMUgAmAruvhgu4JXpRdxOtNyo_YdQg9D18ZTXmDp3_rX42Qrr8DOG8wT4mJeplqiEmgCcmN9EVGfqRSGqrxAYY1tonhe-p9kD16TmDw98ej0afQ8RO1BAhy59H0OlC7gfS1JkoGqcFrF6dLST1QmKJ_W0v5qAGHxCU1KvNSq8zth2v2iYjqteRrDF80Bkn65jYvKyf2pYiF1_VGJhjgS_b4q03IxUJW0Kv_7gTJh-VS29In0HnlxkOcjjFy-N36sXkkiYWLM2QHLWtlEFXedE6FcwuwwmZISYtaV6KwS11x_IEc6aT7GHzViH1lbPRvkEmrEZU__Mw4MbTxOxXFnt8ywptV8wGLJT_9pYN4CX1WC9LtOwLglfFr0iIwi8H3qZhqJLmp0hNq-3HTHi1iSZilWU9fI443Tgsc8_iDi9ek-ENa3QarqCa0gI5n87QpI6pmN8fqSm50dB4kNYiCEB3P_AK2YYveMcxFbdlwEaH7mmOJsAfrFap26_X6ASO6gKbqJN_ycP6WWYE-Yc2ahRShVEAFNtKgND1CmIyTurKVd0vCCye4wqWkeZQiMlbGPGIpsZ_Oemte49lRpbC1mvu0Ds_NSFR2JeMWdwASryh5k5zhPUEQnImHKyJ7hyDSqe1OYzUtWJ8MXFE-t3xd8QRM374DIz8TRyeghYciF5QPzy3LNLy4WgadNre5AZryhMJWI5D5_t-FtwUAzoMAzYGtm84MxQ0Tl4KqhQ2ClyXyZvch-WiO0XCSWwYLDzLrZHsznLmBrV7p7uVmvV1i5i4FpI21ykmOk_3c1_1p7dAfHjc6kE3g8eCv4COQ9ZAYTlxo3bRIwpAMUE_jghiYLwP8dLk0YoRX7HWzl8aLBA6LBbn4jTm6Aq6-A_he3wC9206mhyGVj2_b-L-B8wj-G6FaLcCiHBrtkjH6dAVFoPHTretIJE./download
# Resolving dl.boxcloud.com... 74.112.184.96, 74.112.185.96
# Connecting to dl.boxcloud.com|74.112.184.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72629 (71K) [text/csv]
# Saving to: ‘/resources/FuelConsumption.csv’
#
# 100%[======================================>] 72,629       347KB/s   in 0.2s
#
# 2015-10-05 14:03:52 (347 KB/s) - ‘/resources/FuelConsumption.csv’ saved [72629/72629]

# %%
df = pd.read_csv("/resources/FuelConsumption.csv")

# take a look at the dataset
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
# summarize the data
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count       1067  1067.000000  1067.000000           1067.000000
# mean        2014     3.346298     5.794752             13.296532
# std            0     1.415895     1.797447              4.101253
# min         2014     1.000000     3.000000              4.600000
# 25%         2014     2.000000     4.000000             10.250000
# 50%         2014     3.400000     6.000000             12.600000
# 75%         2014     4.300000     8.000000             15.550000
# max         2014     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %%
viz=df[['CYLINDERS','ENGINESIZE','CO2EMISSIONS','FUELCONSUMPTION_CITY']]
viz.hist()
plt.show()

# %%
plt.scatter(df.ENGINESIZE, df.CO2EMISSIONS)
plt.xlabel("Engine size")
plt.ylabel("Emission Volume")
plt.show()

# %%
msk = np.random.rand(len(df)) < 0.8
trainDf=df[msk]
testDf=df[~msk]

# %% [markdown]
# polyfit --> Least squares polynomial fit
# Degree of the fitting polynomial=1

# %%
fit = np.polyfit(trainDf.ENGINESIZE, trainDf.CO2EMISSIONS, deg=1,full=True)
print 'slope:',fit[0][0]
print 'intercept:',fit[0][1]
print 'residuals (sum of the squares of the fit errors):',fit[1] 
print 'singular values:', fit [3]
print 'conditioning threshold:',fit[4]

fit_fn = np.poly1d(fit[0]) # param: The polynomial’s coefficients
print fit_fn 
plt.plot(trainDf.ENGINESIZE, trainDf.CO2EMISSIONS, 'bo', trainDf.ENGINESIZE, fit_fn(trainDf.ENGINESIZE), '--k')
plt.xlabel("Engine size")
plt.ylabel("Emission Volume")
plt.show()
# Out:
# slope: 38.31192832
# intercept: 128.034056221
# residuals (sum of the squares of the fit errors): [ 789011.39900795]
# singular values: [ 1.38567756  0.28266183]
# conditioning threshold: 1.86295423532e-13
#
# 38.31 x + 128

# %% [markdown]
# ### Test dataset evaluation

# %%
testDf['predicted']= fit_fn(testDf.ENGINESIZE)
plt.plot(testDf.predicted, testDf.CO2EMISSIONS, 'bo', testDf.CO2EMISSIONS, testDf.CO2EMISSIONS, '--k')
plt.xlabel("Predicted Emissions")
plt.ylabel("Emission Volume")
plt.show()
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
